# %%
import pandas as pd
import soundfile as sf
from jiwer import wer
import librosa
import json
import os
import re
from pandarallel import pandarallel
from glob import glob
import torchaudio

pandarallel.initialize(nb_workers=8, progress_bar=False)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
def load_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        lines = f.readlines()
        lines = [json.loads(line.strip()) for line in lines]

    return lines

# %%
log_dir = "/data/codes/apa/kaldi/stt/logs-type-9-v2"
out_path = "/data/codes/apa/kaldi/stt/data/stt-data/infer/info_question_type-9_19092023_21122023.jsonl"

# %%
files = glob(f'{log_dir}/*jsonl')
metadata = []
for file in files:
    metadata += load_jsonl(file)

# %%
df = pd.DataFrame(metadata)
df.head()
# Out:
#        sid  utt_id                                               elsa  \
# 0  6392867       2   Absolutely to are among my favorite closing p...
# 1  6392902       0           No, because my family don't afford with.
# 2  6392902       1                         The the phase of learning.
# 3  6392902       3  , I don't have a chance to learn to play a mus...
# 4  6392911       0                    I think it can be, uh, environ.
#
#                                                 prep  \
# 0  A slowly t shirt are among my favorite closing...
# 1           No, because my family don't afford with.
# 2                              The fees of learning.
# 3  I don't have a chance to learn to play a music...
# 4                       I think it can be a violent.
#
#                                           audio_path
# 0  /data/codes/apa/kaldi/stt/data/stt-data/wav/63...
# 1  /data/codes/apa/kaldi/stt/data/stt-data/wav/63...
# 2  /data/codes/apa/kaldi/stt/data/stt-data/wav/63...
# 3  /data/codes/apa/kaldi/stt/data/stt-data/wav/63...
# 4  /data/codes/apa/kaldi/stt/data/stt-data/wav/63...

# %%
df["sid"] = df["id"]
df["start_time"] = 0
df["utt_id"] = None

# %%
def get_duration(path):
    wav, sr = torchaudio.load(path)
    
    assert sr == 16000
    
    return wav.shape[-1] / sr

df["end_time"] = df.audio_path.parallel_apply(get_duration)

# %%
df.head()
# Out:
#         id  total_time                                               elsa  \
# 0  1177329        7.57  EMMA TOOK ME TO MANY FAMOUS TOURIST ATTRACTION...
# 1  4580473       11.76  EMMA TOOK ME TO MANY FAMOUS TOURIST ATTRACTION...
# 2  1422856        6.64  EMMA TOOK ME TO MANY FAMOUS TOURIST ATTRACTION...
# 3  2150677        6.89  EMMA TOOK ME TO MANY FAMOUS TOURIST ATTRACTION...
# 4  1465808        8.09  EMMA TOOK ME TO MANY FAMOUS TOURIST ATTRACTION...
#
#                                                 prep  \
# 0  And it to me too many famous tourist attractio...
# 1  Ammer took me to many famous tourist attractio...
# 2  And my took me to many famous tourist attracti...
# 3   And took me to any famous tourist attraction of.
# 4   I took me to many famous tourist attractions at.
#
#                                           audio_path      sid  start_time  \
# 0  /data/audio_data/prep_submission_audio/10/1177...  1177329           0
# 1  /data/audio_data/prep_submission_audio/10/4580...  4580473           0
# 2  /data/audio_data/prep_submission_audio/10/1422...  1422856           0
# 3  /data/audio_data/prep_submission_audio/10/2150...  2150677           0
# 4  /data/audio_data/prep_submission_audio/10/1465...  1465808           0
#
#     end_time utt_id
# 0   7.594625   None
# 1  11.776000   None
# 2   6.656000   None
# 3   6.912000   None
# 4   8.106625   None

# %%
with open(out_path, "w", encoding="utf-8") as f:
    for index in df.index:
        row = df.iloc[index].to_dict()
        
        sid = row["sid"]
        start_time = row["start_time"]
        end_time = row["end_time"]
        audio_path = row["audio_path"]
        elsa = row["elsa"]
        prep = row["prep"]
        utt_id = row["utt_id"]
        
        sample = {
            "sid":sid,
            "start_time": start_time,
            "end_time": end_time,
            "audio_path": audio_path,
            "elsa": elsa,
            "prep":prep,
            "utt_id": utt_id
        }
        
        json_obj = json.dumps(sample, ensure_ascii=False)
        f.write(f'{json_obj}\n')

# %%
# with open(out_path, "w", encoding="utf-8") as f:
#     for line in metadata:
#         json_obj = json.dumps(line)
#         f.write(f'{json_obj}\n')
